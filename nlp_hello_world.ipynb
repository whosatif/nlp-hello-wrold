# %% [markdown]
# <a href="https://colab.research.google.com/github/whosatif/nlp-hello-wrold/blob/main/nlp_hello_world.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world");
# Out:
# hello world
